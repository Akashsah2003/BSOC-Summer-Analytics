# %% [markdown]
# # Summer Analytics 2022 - Basic Data Analysis

# %% [markdown]
# - #### Welcome to your second assignment, on basic data analysis!
# - #### This Assignment is ungraded

# %% [markdown]
# ### 1) Import Pandas and Numpy

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### 2) Import the dataset and  Assign it to a variable called Chipo
#
# #### Import the dataset from this url 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv '
# #### REMEMBER: It is a .tsv file , you will have to do some research on how to read .tsv files first!

# %%
df = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv', sep='\t')

# %% [markdown]
# ### 3) See the first 10 entries

# %%
df.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# 5  [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $10.98
# 6                                                NaN     $1.69
# 7  [Tomatillo Red Chili Salsa, [Fajita Vegetables...    $11.75
# 8  [Tomatillo Green Chili Salsa, [Pinto Beans, Ch...     $9.25
# 9  [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...     $9.25

# %% [markdown]
# ### 4) What is the number of observations in the dataset?

# %%
df.shape
# Out:
# (4622, 5)

# %% [markdown]
# ### 5) What is the number of columns in the dataset?

# %%
len(df.columns)
# Out:
# 5

# %% [markdown]
# ### 6) Print the name of all the columns.

# %%
df.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %% [markdown]
# ### 7) Which was the most-ordered item?

# %%
# counting quantity as well
# oifa = np.array([[i,df[df['item_name']==i]['quantity'].sum()] for i in df.item_name.unique()])
# oifdf = pd.DataFrame(oifa, columns=['items','orders'])
# oifdf['orders'] =oifdf['orders'].astype('int32')
# oifdf.sort_values(by = ['orders'], ascending=False, inplace = True)
# oifdf.reset_index(inplace=True)
# oifdf['items'][0]

df['item_name'].value_counts().index[0]
# Out:
# 'Chicken Bowl'

# %% [markdown]
# ### 8) For the most-ordered item, how many items were ordered?

# %%
# counting quantity as well
# oifdf['orders'][0]

df['item_name'].value_counts()[0]
# Out:
# 726

# %% [markdown]
# ### 9) What was the most ordered item in the choice_description column?

# %%
df['choice_description'].value_counts().index[0]
# Out:
# '[Diet Coke]'

# %% [markdown]
# ### 10) How many items were ordered in total?

# %%
df['choice_description'].value_counts()[0]
# Out:
# 134

# %% [markdown]
# ### 11) Turn the item price into a float

# %%
df['item_price'] = df['item_price'].map(lambda s : float(s[1:]))
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 180.7+ KB

# %% [markdown]
# ### 12) How much was the revenue for the period in the dataset?
# #### Revenue will be the sum of quantity * item_price!

# %%
rev=(df['quantity']*df['item_price']).sum()
rev
# Out:
# 39237.02

# %% [markdown]
# ### 13) How many orders were made in the period?

# %%
df.shape[0]
# Out:
# 4622

# %% [markdown]
# ### 14) What is the average revenue amount per order?

# %%
rev/(df.shape[0])
# Out:
# 8.48918649935093

# %% [markdown]
# ### 15) How many different items are sold?

# %%
len(df.item_name.unique())
# Out:
# 50
